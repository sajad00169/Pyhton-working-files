# %%
import pandas as pd

# %%
f500 = pd.read_csv("f500.csv",)

# %%
f500.head()
# Out:
#                     company  rank  revenues  revenue_change  profits  assets  \
# 0                   Walmart     1    485873             0.8  13643.0  198825
# 1                State Grid     2    315199            -4.4   9571.3  489838
# 2             Sinopec Group     3    267518            -9.1   1257.9  310726
# 3  China National Petroleum     4    262573           -12.3   1867.5  585619
# 4              Toyota Motor     5    254694             7.7  16899.3  437575
#
#    profit_change                  ceo                  industry  \
# 0           -7.2  C. Douglas McMillon     General Merchandisers
# 1           -6.2              Kou Wei                 Utilities
# 2          -65.0            Wang Yupu        Petroleum Refining
# 3          -73.7        Zhang Jianhua        Petroleum Refining
# 4          -12.3          Akio Toyoda  Motor Vehicles and Parts
#
#                    sector  previous_rank country      hq_location  \
# ...

# %%
f500.loc[0] # label indexing
# Out:
# company                                    Walmart
# rank                                             1
# revenues                                    485873
# revenue_change                                 0.8
# profits                                    13643.0
# assets                                      198825
# profit_change                                 -7.2
# ceo                            C. Douglas McMillon
# industry                     General Merchandisers
# sector                                   Retailing
# previous_rank                                    1
# country                                        USA
# hq_location                        Bentonville, AR
# website                     http://www.walmart.com
# years_on_global_500_list                        23
# employees                                  2300000
# total_stockholder_equity                     77798
# Name: 0, dtype: object

# %%
# 8gb  - 32gb

# %%
f500.head()
# Out:
#                     company  rank  revenues  revenue_change  profits  assets  \
# 0                   Walmart     1    485873             0.8  13643.0  198825
# 1                State Grid     2    315199            -4.4   9571.3  489838
# 2             Sinopec Group     3    267518            -9.1   1257.9  310726
# 3  China National Petroleum     4    262573           -12.3   1867.5  585619
# 4              Toyota Motor     5    254694             7.7  16899.3  437575
#
#    profit_change                  ceo                  industry  \
# 0           -7.2  C. Douglas McMillon     General Merchandisers
# 1           -6.2              Kou Wei                 Utilities
# 2          -65.0            Wang Yupu        Petroleum Refining
# 3          -73.7        Zhang Jianhua        Petroleum Refining
# 4          -12.3          Akio Toyoda  Motor Vehicles and Parts
#
#                    sector  previous_rank country      hq_location  \
# ...

# %%
f500.loc[1,"rank"]
# Out:
# 2

# %%
f500.at[1,"rank"]
# Out:
# 2

# %%
f500.iat[1,1]
# Out:
# 2

# %%
f500.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   company                   500 non-null    object
#  1   rank                      500 non-null    int64
#  2   revenues                  500 non-null    int64
#  3   revenue_change            498 non-null    float64
#  4   profits                   499 non-null    float64
#  5   assets                    500 non-null    int64
#  6   profit_change             436 non-null    float64
#  7   ceo                       500 non-null    object
#  8   industry                  500 non-null    object
#  9   sector                    500 non-null    object
#  10  previous_rank             500 non-null    int64
#  11  country                   500 non-null    object
#  12  hq_location               500 non-null    object
# ...

# %%
f500.isnull()
# Out:
#      company   rank  revenues  revenue_change  profits  assets  profit_change  \
# 0      False  False     False           False    False   False          False
# 1      False  False     False           False    False   False          False
# 2      False  False     False           False    False   False          False
# 3      False  False     False           False    False   False          False
# 4      False  False     False           False    False   False          False
# ..       ...    ...       ...             ...      ...     ...            ...
# 495    False  False     False           False    False   False          False
# 496    False  False     False           False    False   False          False
# 497    False  False     False           False    False   False          False
# 498    False  False     False           False    False   False          False
# 499    False  False     False           False    False   False          False
#
# ...

# %%
f500.isnull().sum(axis = 0)
# Out:
# company                      0
# rank                         0
# revenues                     0
# revenue_change               2
# profits                      1
# assets                       0
# profit_change               64
# ceo                          0
# industry                     0
# sector                       0
# previous_rank                0
# country                      0
# hq_location                  0
# website                      0
# years_on_global_500_list     0
# employees                    0
# total_stockholder_equity     0
# dtype: int64

# %%
f500.notnull()
# Out:
#      company  rank  revenues  revenue_change  profits  assets  profit_change  \
# 0       True  True      True            True     True    True           True
# 1       True  True      True            True     True    True           True
# 2       True  True      True            True     True    True           True
# 3       True  True      True            True     True    True           True
# 4       True  True      True            True     True    True           True
# ..       ...   ...       ...             ...      ...     ...            ...
# 495     True  True      True            True     True    True           True
# 496     True  True      True            True     True    True           True
# 497     True  True      True            True     True    True           True
# 498     True  True      True            True     True    True           True
# 499     True  True      True            True     True    True           True
#
# ...

# %%
f500.notnull().sum()
# Out:
# company                     500
# rank                        500
# revenues                    500
# revenue_change              498
# profits                     499
# assets                      500
# profit_change               436
# ceo                         500
# industry                    500
# sector                      500
# previous_rank               500
# country                     500
# hq_location                 500
# website                     500
# years_on_global_500_list    500
# employees                   500
# total_stockholder_equity    500
# dtype: int64

# %%
bol = f500["revenue_change"].isnull()

# %%
f500[bol]
# Out:
#                         company  rank  revenues  revenue_change  profits  \
# 90                       Uniper    91     74407             NaN  -3557.5
# 180  Hewlett Packard Enterprise   181     50123             NaN   3161.0
#
#      assets  profit_change                  ceo  \
# 90    51541            NaN        Klaus Schafer
# 180   79679            NaN  Margaret C. Whitman
#
#                             industry      sector  previous_rank  country  \
# 90                            Energy      Energy              0  Germany
# 180  Information Technology Services  Technology              0      USA
#
#              hq_location                   website  years_on_global_500_list  \
# 90   Dusseldorf, Germany  http://www.uniper.energy                         1
# 180        Palo Alto, CA        http://www.hpe.com                         1
#
#      employees  total_stockholder_equity
# 90       12890                     12889
# 180     195000                     31448

# %%
f500[f500["profit_change"].isnull()]
# Out:
#                                           company  rank  revenues  \
# 5                                      Volkswagen     6    240264
# 7                              Berkshire Hathaway     8    223604
# 11                                             BP    12    186606
# 15                                       Glencore    16    173883
# 22                              AmerisourceBergen    23    146850
# ..                                            ...   ...       ...
# 472                                        Altice   473     22953
# 473                                          Onex   474     22943
# 475  Shanxi Jincheng Anthracite Coal Mining Group   476     22875
# 488                                Sears Holdings   489     22138
# 492                                Telecom Italia   493     21941
#
#      revenue_change  profits  assets  profit_change                 ceo  \
# 5               1.5   5937.3  432116            NaN     Matthias Muller
# ...

# %%
f500[f500["profit_change"].isnull()].iloc[63]
# Out:
# company                                   Telecom Italia
# rank                                                 493
# revenues                                           21941
# revenue_change                                     -17.4
# profits                                           1999.4
# assets                                             74295
# profit_change                                        NaN
# ceo                                      Flavio Cattaneo
# industry                              Telecommunications
# sector                                Telecommunications
# previous_rank                                        404
# country                                            Italy
# hq_location                                 Milan, Italy
# website                     http://www.telecomitalia.com
# years_on_global_500_list                              18
# employees                                          61227
# ...

# %%
f500[f500["profit_change"].isnull()].loc[492]
# Out:
# company                                   Telecom Italia
# rank                                                 493
# revenues                                           21941
# revenue_change                                     -17.4
# profits                                           1999.4
# assets                                             74295
# profit_change                                        NaN
# ceo                                      Flavio Cattaneo
# industry                              Telecommunications
# sector                                Telecommunications
# previous_rank                                        404
# country                                            Italy
# hq_location                                 Milan, Italy
# website                     http://www.telecomitalia.com
# years_on_global_500_list                              18
# employees                                          61227
# ...

# %%
f500.head()
# Out:
#                     company  rank  revenues  revenue_change  profits  assets  \
# 0                   Walmart     1    485873             0.8  13643.0  198825
# 1                State Grid     2    315199            -4.4   9571.3  489838
# 2             Sinopec Group     3    267518            -9.1   1257.9  310726
# 3  China National Petroleum     4    262573           -12.3   1867.5  585619
# 4              Toyota Motor     5    254694             7.7  16899.3  437575
#
#    profit_change                  ceo                  industry  \
# 0           -7.2  C. Douglas McMillon     General Merchandisers
# 1           -6.2              Kou Wei                 Utilities
# 2          -65.0            Wang Yupu        Petroleum Refining
# 3          -73.7        Zhang Jianhua        Petroleum Refining
# 4          -12.3          Akio Toyoda  Motor Vehicles and Parts
#
#                    sector  previous_rank country      hq_location  \
# ...

# %%
f500.columns
# Out:
# Index(['company', 'rank', 'revenues', 'revenue_change', 'profits', 'assets',
#        'profit_change', 'ceo', 'industry', 'sector', 'previous_rank',
#        'country', 'hq_location', 'website', 'years_on_global_500_list',
#        'employees', 'total_stockholder_equity'],
#       dtype='object')

# %%
bol = (f500["sector"] == "Energy")  & (f500["country"] != "Japan")

# %%
f500[bol]
# Out:
#                                           company  rank  revenues  \
# 1                                      State Grid     2    315199
# 2                                   Sinopec Group     3    267518
# 3                        China National Petroleum     4    262573
# 6                               Royal Dutch Shell     7    240033
# 9                                     Exxon Mobil    10    205004
# ..                                            ...   ...       ...
# 468                  Enterprise Products Partners   469     23022
# 475  Shanxi Jincheng Anthracite Coal Mining Group   476     22875
# 485                                     GS Caltex   486     22207
# 486                             Ultrapar Holdings   487     22167
# 490                                 National Grid   491     22036
#
#      revenue_change  profits  assets  profit_change              ceo  \
# 1              -4.4   9571.3  489838           -6.2          Kou Wei
# ...

# %%
b = (f500["sector"] == "Energy")  & ~(f500["country"] == "Japan") 

f500[b]
# Out:
#                                           company  rank  revenues  \
# 1                                      State Grid     2    315199
# 2                                   Sinopec Group     3    267518
# 3                        China National Petroleum     4    262573
# 6                               Royal Dutch Shell     7    240033
# 9                                     Exxon Mobil    10    205004
# ..                                            ...   ...       ...
# 468                  Enterprise Products Partners   469     23022
# 475  Shanxi Jincheng Anthracite Coal Mining Group   476     22875
# 485                                     GS Caltex   486     22207
# 486                             Ultrapar Holdings   487     22167
# 490                                 National Grid   491     22036
#
#      revenue_change  profits  assets  profit_change              ceo  \
# 1              -4.4   9571.3  489838           -6.2          Kou Wei
# ...

# %%
f500.head()
# Out:
#                     company  rank  revenues  revenue_change  profits  assets  \
# 0                   Walmart     1    485873             0.8  13643.0  198825
# 1                State Grid     2    315199            -4.4   9571.3  489838
# 2             Sinopec Group     3    267518            -9.1   1257.9  310726
# 3  China National Petroleum     4    262573           -12.3   1867.5  585619
# 4              Toyota Motor     5    254694             7.7  16899.3  437575
#
#    profit_change                  ceo                  industry  \
# 0           -7.2  C. Douglas McMillon     General Merchandisers
# 1           -6.2              Kou Wei                 Utilities
# 2          -65.0            Wang Yupu        Petroleum Refining
# 3          -73.7        Zhang Jianhua        Petroleum Refining
# 4          -12.3          Akio Toyoda  Motor Vehicles and Parts
#
#                    sector  previous_rank country      hq_location  \
# ...

# %%
japan = f500[f500["country"] == "Japan"]

# %%
japan.sort_values("employees", ascending = False).iloc[0][0]
# Out:
# 'Toyota Motor'

# %%
japan.sort_values("employees", ascending = False).iloc[0].iloc[0]
# Out:
# 'Toyota Motor'

# %%
japan.sort_values("employees", ascending = False).iloc[0]["company"]
# Out:
# 'Toyota Motor'

# %%
japan.sort_values("employees", ascending = False).iloc[0].loc["company"]
# Out:
# 'Toyota Motor'

# %%
# japan.sort_values("employees", ascending = False)

# %%
f500["country"].unique()
# Out:
# array(['USA', 'China', 'Japan', 'Germany', 'Netherlands', 'Britain',
#        'South Korea', 'Switzerland', 'France', 'Taiwan', 'Singapore',
#        'Italy', 'Russia', 'Spain', 'Brazil', 'Mexico', 'Luxembourg',
#        'India', 'Malaysia', 'Thailand', 'Australia', 'Belgium', 'Norway',
#        'Canada', 'Ireland', 'Indonesia', 'Denmark', 'Saudi Arabia',
#        'Sweden', 'Finland', 'Venezuela', 'Turkey', 'U.A.E', 'Israel'],
#       dtype=object)

# %%
countries = f500["country"].unique()

# %%
for country in countries:
    print(country)
# Out:
# USA
# China
# Japan
# Germany
# Netherlands
# Britain
# South Korea
# Switzerland
# France
# Taiwan
# Singapore
# Italy
# Russia
# Spain
# Brazil
# Mexico
# Luxembourg
# India
# Malaysia
# Thailand
# Australia
# Belgium
# Norway
# Canada
# Ireland
# Indonesia
# Denmark
# Saudi Arabia
# Sweden
# Finland
# Venezuela
# Turkey
# U.A.E
# Israel

# %%
top_employer = {}

for country in countries:
    df = f500[f500["country"] == country]
    com = df.sort_values("employees", ascending = False).iloc[0]["company"]
    top_employer[country] = com

# %%
print(top_employer)
# Out:
# {'USA': 'Walmart', 'China': 'China National Petroleum', 'Japan': 'Toyota Motor', 'Germany': 'Volkswagen', 'Netherlands': 'EXOR Group', 'Britain': 'Compass Group', 'South Korea': 'Samsung Electronics', 'Switzerland': 'Nestle', 'France': 'Sodexo', 'Taiwan': 'Hon Hai Precision Industry', 'Singapore': 'Flex', 'Italy': 'Poste Italiane', 'Russia': 'Gazprom', 'Spain': 'Banco Santander', 'Brazil': 'JBS', 'Mexico': 'America Movil', 'Luxembourg': 'ArcelorMittal', 'India': 'State Bank of India', 'Malaysia': 'Petronas', 'Thailand': 'PTT', 'Australia': 'Wesfarmers', 'Belgium': 'Anheuser-Busch InBev', 'Norway': 'Statoil', 'Canada': 'George Weston', 'Ireland': 'Accenture', 'Indonesia': 'Pertamina', 'Denmark': 'Maersk Group', 'Saudi Arabia': 'SABIC', 'Sweden': 'H & M Hennes & Mauritz', 'Finland': 'Nokia', 'Venezuela': 'Mercantil Servicios Financieros', 'Turkey': 'Koc Holding', 'U.A.E': 'Emirates Group', 'Israel': 'Teva Pharmaceutical Industries'}

# %%
top_empl = pd.Series()

for country in countries:
    df = f500[f500["country"] == country]
    com = df.sort_values("employees", ascending = False).iloc[0]["company"]
    top_empl[country] = com
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   """Entry point for launching an IPython kernel.

# %%
top_empl
# Out:
# USA                                     Walmart
# China                  China National Petroleum
# Japan                              Toyota Motor
# Germany                              Volkswagen
# Netherlands                          EXOR Group
# Britain                           Compass Group
# South Korea                 Samsung Electronics
# Switzerland                              Nestle
# France                                   Sodexo
# Taiwan               Hon Hai Precision Industry
# Singapore                                  Flex
# Italy                            Poste Italiane
# Russia                                  Gazprom
# Spain                           Banco Santander
# Brazil                                      JBS
# Mexico                            America Movil
# Luxembourg                        ArcelorMittal
# India                       State Bank of India
# Malaysia                               Petronas
# Thailand                                    PTT
# ...

# %%
top_empl = pd.Series(dtype = object)

for country in countries:
    df = f500[f500["country"] == country]
    com = df.sort_values("employees", ascending = False).iloc[0]["company"]
    top_empl[country] = com

# %%
top_empl
# Out:
# USA                                     Walmart
# China                  China National Petroleum
# Japan                              Toyota Motor
# Germany                              Volkswagen
# Netherlands                          EXOR Group
# Britain                           Compass Group
# South Korea                 Samsung Electronics
# Switzerland                              Nestle
# France                                   Sodexo
# Taiwan               Hon Hai Precision Industry
# Singapore                                  Flex
# Italy                            Poste Italiane
# Russia                                  Gazprom
# Spain                           Banco Santander
# Brazil                                      JBS
# Mexico                            America Movil
# Luxembourg                        ArcelorMittal
# India                       State Bank of India
# Malaysia                               Petronas
# Thailand                                    PTT
# ...

# %%
top_empl.sort_index()
# Out:
# Australia                            Wesfarmers
# Belgium                    Anheuser-Busch InBev
# Brazil                                      JBS
# Britain                           Compass Group
# Canada                            George Weston
# China                  China National Petroleum
# Denmark                            Maersk Group
# Finland                                   Nokia
# France                                   Sodexo
# Germany                              Volkswagen
# India                       State Bank of India
# Indonesia                             Pertamina
# Ireland                               Accenture
# Israel           Teva Pharmaceutical Industries
# Italy                            Poste Italiane
# Japan                              Toyota Motor
# Luxembourg                        ArcelorMittal
# Malaysia                               Petronas
# Mexico                            America Movil
# Netherlands                          EXOR Group
# ...

# %%
laptops = pd.read_csv("laptops.csv")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-52-28280099abad> in <module>
# ----> 1 laptops = pd.read_csv("laptops.csv")
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
laptops = pd.read_csv("laptops.csv", 
                      encoding = "unicode_escape") # latin-1(ISO-8895-1),
# unicode_escape, windows-1251

# %%
laptops.head()
# Out:
#   Manufacturer   Model Name   Category Screen Size  \
# 0        Apple  MacBook Pro  Ultrabook       13.3"
# 1        Apple  Macbook Air  Ultrabook       13.3"
# 2           HP       250 G6   Notebook       15.6"
# 3        Apple  MacBook Pro  Ultrabook       15.4"
# 4        Apple  MacBook Pro  Ultrabook       13.3"
#
#                                Screen                         CPU   RAM  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                Storage                           GPU Operating System  \
# 0            128GB SSD  Intel Iris Plus Graphics 640            macOS
# 1  128GB Flash Storage        Intel HD Graphics 6000            macOS
# ...

# %%
laptops.columns
# Out:
# Index(['Manufacturer', 'Model Name', 'Category', 'Screen Size', 'Screen',
#        'CPU', 'RAM', ' Storage', 'GPU', 'Operating System',
#        'Operating System Version', 'Weight', 'Price (Euros)'],
#       dtype='object')

# %%
laptops['Model Name']
# Out:
# 0                               MacBook Pro
# 1                               Macbook Air
# 2                                    250 G6
# 3                               MacBook Pro
# 4                               MacBook Pro
#                        ...
# 1298                         Yoga 500-14ISK
# 1299                         Yoga 900-13ISK
# 1300                     IdeaPad 100S-14IBR
# 1301    15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302    X553SA-XX031T (N3050/4GB/500GB/W10)
# Name: Model Name, Length: 1303, dtype: object

# %%
laptops.CPU
# Out:
# 0                       Intel Core i5 2.3GHz
# 1                       Intel Core i5 1.8GHz
# 2                 Intel Core i5 7200U 2.5GHz
# 3                       Intel Core i7 2.7GHz
# 4                       Intel Core i5 3.1GHz
#                         ...
# 1298              Intel Core i7 6500U 2.5GHz
# 1299              Intel Core i7 6500U 2.5GHz
# 1300    Intel Celeron Dual Core N3050 1.6GHz
# 1301              Intel Core i7 6500U 2.5GHz
# 1302    Intel Celeron Dual Core N3050 1.6GHz
# Name: CPU, Length: 1303, dtype: object

# %%
l = []


for i in laptops.columns:
    # print(i)
    clean = i.strip().lower().replace("operating system", "os")\
    .replace("(","").replace(")", "").replace(" ","_")
    l.append(clean)

# %%
print(l)
# Out:
# ['manufacturer', 'model_name', 'category', 'screen_size', 'screen', 'cpu', 'ram', 'storage', 'gpu', 'os', 'os_version', 'weight', 'price_euros']

# %%
# laptops.columns = l

# %%
laptops.columns = laptops.columns.str.strip().str.lower()\
.str.replace("operating system", "os")\
.str.replace("(","").str.replace(")", "").str.replace(" ","_")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
laptops.head()
# Out:
#   manufacturer   model_name   category screen_size  \
# 0        Apple  MacBook Pro  Ultrabook       13.3"
# 1        Apple  Macbook Air  Ultrabook       13.3"
# 2           HP       250 G6   Notebook       15.6"
# 3        Apple  MacBook Pro  Ultrabook       15.4"
# 4        Apple  MacBook Pro  Ultrabook       13.3"
#
#                                screen                         cpu   ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                storage                           gpu     os os_version  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS        NaN
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS        NaN
# ...

# %%
laptops.ram.str.strip("GB").astype(int)
# Out:
# 0        8
# 1        8
# 2        8
# 3       16
# 4        8
#         ..
# 1298     4
# 1299    16
# 1300     2
# 1301     6
# 1302     4
# Name: ram, Length: 1303, dtype: int32

# %%
laptops["ram"] = laptops.ram.str.strip("GB").astype(int)

# %%
laptops
# Out:
#      manufacturer                           model_name            category  \
# 0           Apple                          MacBook Pro           Ultrabook
# 1           Apple                          Macbook Air           Ultrabook
# 2              HP                               250 G6            Notebook
# 3           Apple                          MacBook Pro           Ultrabook
# 4           Apple                          MacBook Pro           Ultrabook
# ...           ...                                  ...                 ...
# 1298       Lenovo                       Yoga 500-14ISK  2 in 1 Convertible
# 1299       Lenovo                       Yoga 900-13ISK  2 in 1 Convertible
# 1300       Lenovo                   IdeaPad 100S-14IBR            Notebook
# 1301           HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook
# 1302         Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook
#
#      screen_size                                      screen  \
# ...

# %%
# laptops.columns = laptops.columns.str.replace("ram", "ram_gb")

# %%
# laptops = laptops.rename({"ram": "ram_gb"}, axis = 1 )

laptops.rename({"ram": "ram_gb"}, 
               axis = 1,
               inplace = True)

# %%
laptops.head()
# Out:
#   manufacturer   model_name   category screen_size  \
# 0        Apple  MacBook Pro  Ultrabook       13.3"
# 1        Apple  Macbook Air  Ultrabook       13.3"
# 2           HP       250 G6   Notebook       15.6"
# 3        Apple  MacBook Pro  Ultrabook       15.4"
# 4        Apple  MacBook Pro  Ultrabook       13.3"
#
#                                screen                         cpu  ram_gb  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz       8
# 1                            1440x900        Intel Core i5 1.8GHz       8
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz       8
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz      16
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz       8
#
#                storage                           gpu     os os_version  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS        NaN
# ...
