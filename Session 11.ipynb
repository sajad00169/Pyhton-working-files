# %%
import csv

# %%
# list(csv.reader(open("dataset_hybrid.csv", encoding = "utf-8")))

# list(csv.reader(open("dataset_online.csv", encoding = "utf-8")))

# %%
hacker = list(csv.reader(open("hacker.csv")))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 hacker = list(csv.reader(open("hacker.csv")))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'hacker.csv'

# %%
print(hacker[:10])
# Out:
# [['id', 'title', 'url', 'num_points', 'num_comments', 'author', 'created_at'], ['12224879', 'Interactive Dynamic Video', 'http://www.interactivedynamicvideo.com/', '386', '52', 'ne0phyte', '8/4/2016 11:52'], ['10975351', 'How to Use Open Source and Shut the Fuck Up at the Same Time', 'http://hueniverse.com/2016/01/26/how-to-use-open-source-and-shut-the-fuck-up-at-the-same-time/', '39', '10', 'josep2', '1/26/2016 19:30'], ['11964716', "Florida DJs May Face Felony for April Fools' Water Joke", 'http://www.thewire.com/entertainment/2013/04/florida-djs-april-fools-water-joke/63798/', '2', '1', 'vezycash', '6/23/2016 22:20'], ['11919867', 'Technology ventures: From Idea to Enterprise', 'https://www.amazon.com/Technology-Ventures-Enterprise-Thomas-Byers/dp/0073523429', '3', '1', 'hswarna', '6/17/2016 0:01'], ['10301696', 'Note by Note: The Making of Steinway L1037 (2007)', 'http://www.nytimes.com/2007/11/07/movies/07stein.html?_r=0', '8', '2', 'walterbell', '9/30/2015 4:12'], ['10482257', 
# ...

# %%
len(hacker)
# Out:
# 20101

# %%
headers = hacker[0]

# %%
data = hacker[1:]

# %%
# for row in data:
#     print(row[1])

# %%
# for row in data:
#     if row[1].lower().startswith("ask") or row[1].lower().startswith("show"):
#         print(row[1])

# %%
ask = []
show = []

for row in data:
    if row[1].lower().startswith("ask"):
        ask.append(row)
    elif row[1].lower().startswith("show"):
        show.append(row)

# %%
print(ask[:3])
# Out:
# [['12296411', 'Ask HN: How to improve my personal website?', '', '2', '6', 'ahmedbaracat', '8/16/2016 9:55'], ['10610020', 'Ask HN: Am I the only one outraged by Twitter shutting down share counts?', '', '28', '29', 'tkfx', '11/22/2015 13:43'], ['11610310', 'Ask HN: Aby recent changes to CSS that broke mobile?', '', '1', '1', 'polskibus', '5/2/2016 10:14']]

# %%
print(show[:3])
# Out:
# [['10627194', 'Show HN: Wio Link  ESP8266 Based Web of Things Hardware Development Platform', 'https://iot.seeed.cc', '26', '22', 'kfihihc', '11/25/2015 14:03'], ['10646440', 'Show HN: Something pointless I made', 'http://dn.ht/picklecat/', '747', '102', 'dhotson', '11/29/2015 22:46'], ['11590768', 'Show HN: Shanhu.io, a programming playground powered by e8vm', 'https://shanhu.io', '1', '1', 'h8liu', '4/28/2016 18:05']]

# %%
len(ask)
# Out:
# 1756

# %%
len(show)
# Out:
# 1164

# %%
avg_ask_cm = 0
avg_show_cm = 0

for row in ask:
    print(type(row[4]))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# ...

# %%
total_ask_cm = 0
total_show_cm = 0

for row in ask:
    total_ask_cm+= int(row[4])
    
for row in show:
    total_show_cm+= int(row[4])

# %%
total_ask_cm
# Out:
# 24941

# %%
total_show_cm
# Out:
# 12016

# %%
avg_ask = total_ask_cm/len(ask)
avg_show = total_show_cm/len(show)

# %%
print(avg_ask, avg_show)
# Out:
# 14.203302961275627 10.323024054982818

# %%
for row in ask[:3]:
    print(row)
# Out:
# ['12296411', 'Ask HN: How to improve my personal website?', '', '2', '6', 'ahmedbaracat', '8/16/2016 9:55']
# ['10610020', 'Ask HN: Am I the only one outraged by Twitter shutting down share counts?', '', '28', '29', 'tkfx', '11/22/2015 13:43']
# ['11610310', 'Ask HN: Aby recent changes to CSS that broke mobile?', '', '1', '1', 'polskibus', '5/2/2016 10:14']

# %%
import datetime as dt

# %%
for row in ask[:3]:
    hr = dt.datetime.strptime(row[-1], "%m/%d/%Y %H:%M").hour
    print(hr)
# Out:
# 9
# 13
# 10

# %%
# 9  no_com/total_cmt

# avg cmt per hours
avg_h_c = {}

# %%
dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i2',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'exit',
#  'get_ipython',
#  'quit']

# %%
import os
os. getcwd()
# Out:
# 'C:\\Users\\Sajad Shah\\Matlab_Folder'
