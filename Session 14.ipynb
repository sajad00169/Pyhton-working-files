# %%
import pandas as pd

# %%
f500 = pd.read_csv("f500.csv", index_col = 0)

# %%
f500.head()
# Out:
#                           rank  revenues  revenue_change  profits  assets  \
# company
# Walmart                      1    485873             0.8  13643.0  198825
# State Grid                   2    315199            -4.4   9571.3  489838
# Sinopec Group                3    267518            -9.1   1257.9  310726
# China National Petroleum     4    262573           -12.3   1867.5  585619
# Toyota Motor                 5    254694             7.7  16899.3  437575
#
#                           profit_change                  ceo  \
# company
# Walmart                            -7.2  C. Douglas McMillon
# State Grid                         -6.2              Kou Wei
# Sinopec Group                     -65.0            Wang Yupu
# China National Petroleum          -73.7        Zhang Jianhua
# Toyota Motor                      -12.3          Akio Toyoda
#
#                                           industry                  sector  \
# company
# ...

# %%
f500.shape
# Out:
# (500, 16)

# %%
type(f500)
# Out:
# pandas.core.frame.DataFrame

# %%
f500.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 500 entries, Walmart to AutoNation
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   rank                      500 non-null    int64
#  1   revenues                  500 non-null    int64
#  2   revenue_change            498 non-null    float64
#  3   profits                   499 non-null    float64
#  4   assets                    500 non-null    int64
#  5   profit_change             436 non-null    float64
#  6   ceo                       500 non-null    object
#  7   industry                  500 non-null    object
#  8   sector                    500 non-null    object
#  9   previous_rank             500 non-null    int64
#  10  country                   500 non-null    object
#  11  hq_location               500 non-null    object
#  12  website                   500 non-null    object
# ...

# %%
# commit, rollback

# %%
f500.dtypes
# Out:
# rank                          int64
# revenues                      int64
# revenue_change              float64
# profits                     float64
# assets                        int64
# profit_change               float64
# ceo                          object
# industry                     object
# sector                       object
# previous_rank                 int64
# country                      object
# hq_location                  object
# website                      object
# years_on_global_500_list      int64
# employees                     int64
# total_stockholder_equity      int64
# dtype: object

# %%
# axes

# %%
f500.head(2)
# Out:
#             rank  revenues  revenue_change  profits  assets  profit_change  \
# company
# Walmart        1    485873             0.8  13643.0  198825           -7.2
# State Grid     2    315199            -4.4   9571.3  489838           -6.2
#
#                             ceo               industry     sector  \
# company
# Walmart     C. Douglas McMillon  General Merchandisers  Retailing
# State Grid              Kou Wei              Utilities     Energy
#
#             previous_rank country      hq_location                 website  \
# company
# Walmart                 1     USA  Bentonville, AR  http://www.walmart.com
# State Grid              2   China   Beijing, China  http://www.sgcc.com.cn
#
#             years_on_global_500_list  employees  total_stockholder_equity
# company
# Walmart                           23    2300000                     77798
# State Grid                        17     926067                    209456

# %%
f500.index.name
# Out:
# 'company'

# %%
f500.index.name = None

# %%
f500.index.name

# %%
print(f500.index.name)
# Out:
# None

# %%
f500["ceo"]
# Out:
# Walmart                           C. Douglas McMillon
# State Grid                                    Kou Wei
# Sinopec Group                               Wang Yupu
# China National Petroleum                Zhang Jianhua
# Toyota Motor                              Akio Toyoda
#                                          ...
# Teva Pharmaceutical Industries      Yitzhak Peterburg
# New China Life Insurance                     Wan Feng
# Wm. Morrison Supermarkets              David T. Potts
# TUI                                 Friedrich Joussen
# AutoNation                         Michael J. Jackson
# Name: ceo, Length: 500, dtype: object

# %%
f500["ceo"].ndim
# Out:
# 1

# %%
type(f500["ceo"]) # 1darray, list
# Out:
# pandas.core.series.Series

# %%
f500[["rank", "industry"]]
# Out:
#                                 rank                         industry
# Walmart                            1            General Merchandisers
# State Grid                         2                        Utilities
# Sinopec Group                      3               Petroleum Refining
# China National Petroleum           4               Petroleum Refining
# Toyota Motor                       5         Motor Vehicles and Parts
# ...                              ...                              ...
# Teva Pharmaceutical Industries   496                  Pharmaceuticals
# New China Life Insurance         497  Insurance: Life, Health (stock)
# Wm. Morrison Supermarkets        498             Food and Drug Stores
# TUI                              499                  Travel Services
# AutoNation                       500              Specialty Retailers
#
# [500 rows x 2 columns]

# %%
f500.industry
# Out:
# Walmart                                     General Merchandisers
# State Grid                                              Utilities
# Sinopec Group                                  Petroleum Refining
# China National Petroleum                       Petroleum Refining
# Toyota Motor                             Motor Vehicles and Parts
#                                                ...
# Teva Pharmaceutical Industries                    Pharmaceuticals
# New China Life Insurance          Insurance: Life, Health (stock)
# Wm. Morrison Supermarkets                    Food and Drug Stores
# TUI                                               Travel Services
# AutoNation                                    Specialty Retailers
# Name: industry, Length: 500, dtype: object

# %%
f500.iloc[1]
# Out:
# rank                                             2
# revenues                                    315199
# revenue_change                                -4.4
# profits                                     9571.3
# assets                                      489838
# profit_change                                 -6.2
# ceo                                        Kou Wei
# industry                                 Utilities
# sector                                      Energy
# previous_rank                                    2
# country                                      China
# hq_location                         Beijing, China
# website                     http://www.sgcc.com.cn
# years_on_global_500_list                        17
# employees                                   926067
# total_stockholder_equity                    209456
# Name: State Grid, dtype: object

# %%
f500.loc["State Grid"]
# Out:
# rank                                             2
# revenues                                    315199
# revenue_change                                -4.4
# profits                                     9571.3
# assets                                      489838
# profit_change                                 -6.2
# ceo                                        Kou Wei
# industry                                 Utilities
# sector                                      Energy
# previous_rank                                    2
# country                                      China
# hq_location                         Beijing, China
# website                     http://www.sgcc.com.cn
# years_on_global_500_list                        17
# employees                                   926067
# total_stockholder_equity                    209456
# Name: State Grid, dtype: object

# %%
f500.loc[["Walmart", "Toyota Motor"]]
# Out:
#               rank  revenues  revenue_change  profits  assets  profit_change  \
# Walmart          1    485873             0.8  13643.0  198825           -7.2
# Toyota Motor     5    254694             7.7  16899.3  437575          -12.3
#
#                               ceo                  industry  \
# Walmart       C. Douglas McMillon     General Merchandisers
# Toyota Motor          Akio Toyoda  Motor Vehicles and Parts
#
#                               sector  previous_rank country      hq_location  \
# Walmart                    Retailing              1     USA  Bentonville, AR
# Toyota Motor  Motor Vehicles & Parts              8   Japan    Toyota, Japan
#
#                                    website  years_on_global_500_list  \
# Walmart             http://www.walmart.com                        23
# Toyota Motor  http://www.toyota-global.com                        23
#
#               employees  total_stockholder_equity
# Walmart         2300000                     77798
# ...

# %%
f500.iloc[[0, 4]]
# Out:
#               rank  revenues  revenue_change  profits  assets  profit_change  \
# Walmart          1    485873             0.8  13643.0  198825           -7.2
# Toyota Motor     5    254694             7.7  16899.3  437575          -12.3
#
#                               ceo                  industry  \
# Walmart       C. Douglas McMillon     General Merchandisers
# Toyota Motor          Akio Toyoda  Motor Vehicles and Parts
#
#                               sector  previous_rank country      hq_location  \
# Walmart                    Retailing              1     USA  Bentonville, AR
# Toyota Motor  Motor Vehicles & Parts              8   Japan    Toyota, Japan
#
#                                    website  years_on_global_500_list  \
# Walmart             http://www.walmart.com                        23
# Toyota Motor  http://www.toyota-global.com                        23
#
#               employees  total_stockholder_equity
# Walmart         2300000                     77798
# ...

# %%
f500.loc[["Walmart", "Toyota Motor"],["ceo", "industry"]]
# Out:
#                               ceo                  industry
# Walmart       C. Douglas McMillon     General Merchandisers
# Toyota Motor          Akio Toyoda  Motor Vehicles and Parts

# %%
f500.iloc[[0, 4],[6, 7]]
# Out:
#                               ceo                  industry
# Walmart       C. Douglas McMillon     General Merchandisers
# Toyota Motor          Akio Toyoda  Motor Vehicles and Parts

# %%
# regular expression

# %%
# bol = f500["industry"].str.lower().str.contains(r"mo")

# %%
# f500[bol]

# %%
# f500.loc[:,"assets": "sector"]
f500.iloc[:,4: 8]
# f500["assets": "sector"]
# Out:
#                                 assets  profit_change                  ceo  \
# Walmart                         198825           -7.2  C. Douglas McMillon
# State Grid                      489838           -6.2              Kou Wei
# Sinopec Group                   310726          -65.0            Wang Yupu
# China National Petroleum        585619          -73.7        Zhang Jianhua
# Toyota Motor                    437575          -12.3          Akio Toyoda
# ...                                ...            ...                  ...
# Teva Pharmaceutical Industries   92890          -79.3    Yitzhak Peterburg
# New China Life Insurance        100609          -45.6             Wan Feng
# Wm. Morrison Supermarkets        11630           20.4       David T. Potts
# TUI                              16247          195.5    Friedrich Joussen
# AutoNation                       10060           -2.7   Michael J. Jackson
#
#                                                        industry
# ...

# %%
f500["Teva Pharmaceutical Industries": "TUI"] #
# Out:
#                                 rank  revenues  revenue_change  profits  \
# Teva Pharmaceutical Industries   496     21903            11.5    329.0
# New China Life Insurance         497     21796           -13.3    743.9
# Wm. Morrison Supermarkets        498     21741           -11.3    406.4
# TUI                              499     21655            -5.5   1151.7
#
#                                 assets  profit_change                ceo  \
# Teva Pharmaceutical Industries   92890          -79.3  Yitzhak Peterburg
# New China Life Insurance        100609          -45.6           Wan Feng
# Wm. Morrison Supermarkets        11630           20.4     David T. Potts
# TUI                              16247          195.5  Friedrich Joussen
#
#                                                        industry  \
# Teva Pharmaceutical Industries                  Pharmaceuticals
# New China Life Insurance        Insurance: Life, Health (stock)
# ...

# %%
f500.head(15)
# Out:
#                           rank  revenues  revenue_change  profits  assets  \
# Walmart                      1    485873             0.8  13643.0  198825
# State Grid                   2    315199            -4.4   9571.3  489838
# Sinopec Group                3    267518            -9.1   1257.9  310726
# China National Petroleum     4    262573           -12.3   1867.5  585619
# Toyota Motor                 5    254694             7.7  16899.3  437575
# Volkswagen                   6    240264             1.5   5937.3  432116
# Royal Dutch Shell            7    240033           -11.8   4575.0  411275
# Berkshire Hathaway           8    223604             6.1  24074.0  620854
# Apple                        9    215639            -7.7  45687.0  321686
# Exxon Mobil                 10    205004           -16.7   7840.0  330314
# McKesson                    11    198533             3.1   5070.0   60969
# BP                          12    186606           -17.4    115.0  263316
# ...

# %%
f500.loc[["Toyota Motor", "Apple", "BP"],["website","rank"]]
# Out:
#                                    website  rank
# Toyota Motor  http://www.toyota-global.com     5
# Apple                 http://www.apple.com     9
# BP                       http://www.bp.com    12

# %%
f500["country"]
# Out:
# Walmart                               USA
# State Grid                          China
# Sinopec Group                       China
# China National Petroleum            China
# Toyota Motor                        Japan
#                                    ...
# Teva Pharmaceutical Industries     Israel
# New China Life Insurance            China
# Wm. Morrison Supermarkets         Britain
# TUI                               Germany
# AutoNation                            USA
# Name: country, Length: 500, dtype: object

# %%
for i in f500["country"]:
    print(i)
# Out:
# USA
# China
# China
# China
# Japan
# Germany
# Netherlands
# USA
# USA
# USA
# USA
# Britain
# USA
# USA
# South Korea
# Switzerland
# Germany
# USA
# USA
# Netherlands
# USA
# China
# USA
# China
# France
# USA
# Taiwan
# China
# Japan
# France
# USA
# USA
# Japan
# Germany
# USA
# USA
# USA
# China
# China
# USA
# China
# China
# France
# Japan
# USA
# USA
# China
# USA
# Britain
# Japan
# China
# Germany
# USA
# Singapore
# China
# Britain
# Italy
# China
# USA
# USA
# USA
# USA
# Russia
# Switzerland
# USA
# Germany
# France
# China
# USA
# USA
# Japan
# Japan
# Spain
# USA
# Brazil
# Germany
# Germany
# South Korea
# USA
# France
# USA
# France
# China
# Italy
# USA
# China
# Japan
# Britain
# China
# Britain
# Germany
# Britain
# France
# Netherlands
# South Korea
# USA
# USA
# USA
# USA
# China
# China
# Russia
# China
# France
# Japan
# USA
# USA
# France
# Germany
# Japan
# Japan
# Switzerland
# Brazil
# China
# China
# Japan
# Germany
# USA
# China
# China
# Britain
# USA
# ...

# %%
d = {}
for country in f500["country"]:
    if country not in d:
        d[country] = 1
    else:
        d[country] += 1

# %%
print(d)
# Out:
# {'USA': 132, 'China': 109, 'Japan': 51, 'Germany': 29, 'Netherlands': 14, 'Britain': 24, 'South Korea': 15, 'Switzerland': 14, 'France': 29, 'Taiwan': 6, 'Singapore': 3, 'Italy': 7, 'Russia': 4, 'Spain': 9, 'Brazil': 7, 'Mexico': 2, 'Luxembourg': 1, 'India': 7, 'Malaysia': 1, 'Thailand': 1, 'Australia': 7, 'Belgium': 1, 'Norway': 1, 'Canada': 11, 'Ireland': 4, 'Indonesia': 1, 'Denmark': 1, 'Saudi Arabia': 1, 'Sweden': 3, 'Finland': 1, 'Venezuela': 1, 'Turkey': 1, 'U.A.E': 1, 'Israel': 1}

# %%
# pd.Series(d).sort_values(ascending = False)

# %%
f500["country"].value_counts() # why should we reinvent the wheel
# Frequeny Distribution Table
# Out:
# USA             132
# China           109
# Japan            51
# Germany          29
# France           29
# Britain          24
# South Korea      15
# Netherlands      14
# Switzerland      14
# Canada           11
# Spain             9
# Australia         7
# Brazil            7
# India             7
# Italy             7
# Taiwan            6
# Russia            4
# Ireland           4
# Singapore         3
# Sweden            3
# Mexico            2
# Malaysia          1
# Thailand          1
# Belgium           1
# Norway            1
# Luxembourg        1
# Indonesia         1
# Denmark           1
# Saudi Arabia      1
# Finland           1
# Venezuela         1
# Turkey            1
# U.A.E             1
# Israel            1
# Name: country, dtype: int64

# %%
f500["country"].shape
# Out:
# (500,)

# %%
# f500["country"].to_dict()

# %%
f500.head(20)
# Out:
#                           rank  revenues  revenue_change  profits  assets  \
# Walmart                      1    485873             0.8  13643.0  198825
# State Grid                   2    315199            -4.4   9571.3  489838
# Sinopec Group                3    267518            -9.1   1257.9  310726
# China National Petroleum     4    262573           -12.3   1867.5  585619
# Toyota Motor                 5    254694             7.7  16899.3  437575
# Volkswagen                   6    240264             1.5   5937.3  432116
# Royal Dutch Shell            7    240033           -11.8   4575.0  411275
# Berkshire Hathaway           8    223604             6.1  24074.0  620854
# Apple                        9    215639            -7.7  45687.0  321686
# Exxon Mobil                 10    205004           -16.7   7840.0  330314
# McKesson                    11    198533             3.1   5070.0   60969
# BP                          12    186606           -17.4    115.0  263316
# ...

# %%
# rev - cost = profit

# rev - prof = cos

# %%
f500.columns
# Out:
# Index(['rank', 'revenues', 'revenue_change', 'profits', 'assets',
#        'profit_change', 'ceo', 'industry', 'sector', 'previous_rank',
#        'country', 'hq_location', 'website', 'years_on_global_500_list',
#        'employees', 'total_stockholder_equity'],
#       dtype='object')

# %%
costs = f500["revenues"] - f500["profits"]

# %%
costs
# Out:
# Walmart                           472230.0
# State Grid                        305627.7
# Sinopec Group                     266260.1
# China National Petroleum          260705.5
# Toyota Motor                      237794.7
#                                     ...
# Teva Pharmaceutical Industries     21574.0
# New China Life Insurance           21052.1
# Wm. Morrison Supermarkets          21334.6
# TUI                                20503.3
# AutoNation                         21178.5
# Length: 500, dtype: float64

# %%
f500["costs"] = costs

# %%
f500
# Out:
#                                 rank  revenues  revenue_change  profits  \
# Walmart                            1    485873             0.8  13643.0
# State Grid                         2    315199            -4.4   9571.3
# Sinopec Group                      3    267518            -9.1   1257.9
# China National Petroleum           4    262573           -12.3   1867.5
# Toyota Motor                       5    254694             7.7  16899.3
# ...                              ...       ...             ...      ...
# Teva Pharmaceutical Industries   496     21903            11.5    329.0
# New China Life Insurance         497     21796           -13.3    743.9
# Wm. Morrison Supermarkets        498     21741           -11.3    406.4
# TUI                              499     21655            -5.5   1151.7
# AutoNation                       500     21609             3.6    430.5
#
#                                 assets  profit_change                  ceo  \
# ...

# %%
# del f500["costs"]

# f500 = f500.drop("costs", axis = 1)

f500.drop("costs", axis = 1, inplace = True)

# %%
f500.columns
# Out:
# Index(['rank', 'revenues', 'revenue_change', 'profits', 'assets',
#        'profit_change', 'ceo', 'industry', 'sector', 'previous_rank',
#        'country', 'hq_location', 'website', 'years_on_global_500_list',
#        'employees', 'total_stockholder_equity'],
#       dtype='object')

# %%
dir(f500)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
# ...

# %%
f500.insert(3,"costs",costs)

# %%
f500
# Out:
#                                 rank  revenues  revenue_change     costs  \
# Walmart                            1    485873             0.8  472230.0
# State Grid                         2    315199            -4.4  305627.7
# Sinopec Group                      3    267518            -9.1  266260.1
# China National Petroleum           4    262573           -12.3  260705.5
# Toyota Motor                       5    254694             7.7  237794.7
# ...                              ...       ...             ...       ...
# Teva Pharmaceutical Industries   496     21903            11.5   21574.0
# New China Life Insurance         497     21796           -13.3   21052.1
# Wm. Morrison Supermarkets        498     21741           -11.3   21334.6
# TUI                              499     21655            -5.5   20503.3
# AutoNation                       500     21609             3.6   21178.5
#
#                                 profits  assets  profit_change  \
# ...

# %% [markdown]
# There is nothing free in the market. If something is free then you are product

# %%
f500.describe()
# Out:
#              rank       revenues  revenue_change          costs       profits  \
# count  500.000000     500.000000      498.000000     499.000000    499.000000
# mean   250.500000   55416.358000        4.538353   52424.528257   3055.203206
# std    144.481833   45725.478963       28.549067   43762.033448   5171.981071
# min      1.000000   21609.000000      -67.300000   11885.400000 -13038.000000
# 25%    125.750000   29003.000000       -5.900000   27125.650000    556.950000
# 50%    250.500000   40236.000000        0.550000   38175.000000   1761.600000
# 75%    375.250000   63926.750000        6.975000   62037.850000   3954.000000
# max    500.000000  485873.000000      442.300000  472230.000000  45687.000000
#
#              assets  profit_change  previous_rank  years_on_global_500_list  \
# count  5.000000e+02     436.000000     500.000000                500.000000
# mean   2.436323e+05      24.152752     222.134000                 15.036000
# ...

# %%
f500.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 500 entries, Walmart to AutoNation
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   rank                      500 non-null    int64
#  1   revenues                  500 non-null    int64
#  2   revenue_change            498 non-null    float64
#  3   costs                     499 non-null    float64
#  4   profits                   499 non-null    float64
#  5   assets                    500 non-null    int64
#  6   profit_change             436 non-null    float64
#  7   ceo                       500 non-null    object
#  8   industry                  500 non-null    object
#  9   sector                    500 non-null    object
#  10  previous_rank             500 non-null    int64
#  11  country                   500 non-null    object
#  12  hq_location               500 non-null    object
# ...

# %%
# f500.describe(include = "all")

# %%
f500.describe(include = "O")
# Out:
#                         ceo                       industry      sector  \
# count                   500                            500         500
# unique                  500                             58          21
# top     C. Douglas McMillon  Banks: Commercial and Savings  Financials
# freq                      1                             51         118
#
#        country     hq_location                 website
# count      500             500                     500
# unique      34             235                     500
# top        USA  Beijing, China  http://www.walmart.com
# freq       132              56                       1

# %%
f500["ceo"].describe()
# Out:
# count                     500
# unique                    500
# top       C. Douglas McMillon
# freq                        1
# Name: ceo, dtype: object

# %%
f500["sector"].describe()
# Out:
# count            500
# unique            21
# top       Financials
# freq             118
# Name: sector, dtype: object

# %%
s = f500["country"].value_counts()

# %%
s.to_csv("Series.csv")

# %%
f500.describe(include = "all")
# Out:
#               rank       revenues  revenue_change          costs  \
# count   500.000000     500.000000      498.000000     499.000000
# unique         NaN            NaN             NaN            NaN
# top            NaN            NaN             NaN            NaN
# freq           NaN            NaN             NaN            NaN
# mean    250.500000   55416.358000        4.538353   52424.528257
# std     144.481833   45725.478963       28.549067   43762.033448
# min       1.000000   21609.000000      -67.300000   11885.400000
# 25%     125.750000   29003.000000       -5.900000   27125.650000
# 50%     250.500000   40236.000000        0.550000   38175.000000
# 75%     375.250000   63926.750000        6.975000   62037.850000
# max     500.000000  485873.000000      442.300000  472230.000000
#
#              profits        assets  profit_change                  ceo  \
# count     499.000000  5.000000e+02     436.000000                  500
# ...
